# %% [markdown]
# ## Load packages

# %%
import pandas as pd
import numpy as np
import random
import re
import os

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from scipy.stats import zscore

# %% [markdown]
# ## Load and inspect data

# %%
sentencing_data_cleaned = pd.read_csv("../Data/sentencing_cleaned.csv", low_memory = False)

print(sentencing_data_cleaned.head())
print(sentencing_data_cleaned.shape)
print(sentencing_data_cleaned.info)

sentencing_data_cleaned.columns
# Out:
#         CASE_ID  CASE_PARTICIPANT_ID          RECEIVED_DATE  \
# 0  149765331439         175691153649  8/15/1984 12:00:00 AM
# 1  150065796098         162105612284  8/23/1984 12:00:00 AM
# 2  154954734978         225758446387   6/8/2001 12:00:00 AM
# 3  155222744754         217349881776  1/31/2001 12:00:00 AM
# 4  155327892699         217212381455   2/6/2001 12:00:00 AM
#
#     OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG    CHARGE_ID  CHARGE_VERSION_ID  \
# 0  PROMIS Conversion                 True  50510062193       112898098217
# 1  PROMIS Conversion                 True  50792360681       113332130159
# 2  PROMIS Conversion                 True  54885211141       174293345821
# 3  PROMIS Conversion                 True  53899906462       280120721775
# 4  PROMIS Conversion                 True  53938518259       164877860811
#
#                    DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 0                                FIRST DEGREE MURDER             1
# 1                                FIRST DEGREE MURDER             1
# 2                              VIO BAIL BOND/CLASS 1             1
# 3                    POSS AMT CON SUB EXCEPT (A)/(D)             1
# 4  DUI LIC SUSPENDED OR REVOKED (EFFECTIVE 4-13-2...             1
#
#          DISPOSITION_DATE  ... simplified_offense_derived is_black_derived  \
# 0  12/17/2014 12:00:00 AM  ...                   Homicide             True
# 1    8/6/2014 12:00:00 AM  ...                   Homicide             True
# 2   12/2/2013 12:00:00 AM  ...          PROMIS Conversion            False
# 3   9/10/2012 12:00:00 AM  ...                  Narcotics             True
# 4   9/19/2014 12:00:00 AM  ...          PROMIS Conversion            False
#
#   is_hisp_derived is_white_derived is_other_derived is_male_derived  \
# 0           False            False            False            True
# 1           False            False            False            True
# 2            True            False            False            True
# 3           False            False            False           False
# 4           False             True            False            True
#
#   age_derived sentenceymd_derived sentenceym_derived judgeid_derived
# 0        27.0          2014-10-16         2014-10-01        judge_40
# 1        30.0          2014-08-06         2014-08-01       judge_310
# 2        38.0          2013-12-02         2013-12-01       judge_162
# 3        33.0          2012-09-10         2012-09-01       judge_331
# 4        49.0          2014-09-19         2014-09-01       judge_314
#
# [5 rows x 52 columns]
# (135165, 52)
# <bound method DataFrame.info of              CASE_ID  CASE_PARTICIPANT_ID          RECEIVED_DATE  \
# 0       149765331439         175691153649  8/15/1984 12:00:00 AM
# 1       150065796098         162105612284  8/23/1984 12:00:00 AM
# 2       154954734978         225758446387   6/8/2001 12:00:00 AM
# 3       155222744754         217349881776  1/31/2001 12:00:00 AM
# 4       155327892699         217212381455   2/6/2001 12:00:00 AM
# ...              ...                  ...                    ...
# 135160  445516248775         905289187184   2/3/2021 12:00:00 AM
# 135161  445527409730         905322500577   2/4/2021 12:00:00 AM
# 135162  445587767000         905518794790   2/9/2021 12:00:00 AM
# 135163  445592613204         905533705601   2/9/2021 12:00:00 AM
# 135164  445593200623         905535215556   2/9/2021 12:00:00 AM
#
#                                  OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG  \
# 0                               PROMIS Conversion                 True
# 1                               PROMIS Conversion                 True
# 2                               PROMIS Conversion                 True
# 3                               PROMIS Conversion                 True
# 4                               PROMIS Conversion                 True
# ...                                           ...                  ...
# 135160                              Home Invasion                 True
# 135161                           Domestic Battery                 True
# 135162  Driving With Suspended Or Revoked License                 True
# 135163  Driving With Suspended Or Revoked License                 True
# 135164  Driving With Suspended Or Revoked License                 True
#
#            CHARGE_ID  CHARGE_VERSION_ID  \
# 0        50510062193       112898098217
# 1        50792360681       113332130159
# 2        54885211141       174293345821
# 3        53899906462       280120721775
# 4        53938518259       164877860811
# ...              ...                ...
# 135160  447867029248       836341344232
# 135161  447970697900       836537247156
# 135162  447955866546       837760215766
# 135163  447966223356       837758347354
# 135164  447966323908       837759561822
#
#                         DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 0                                     FIRST DEGREE MURDER             1
# 1                                     FIRST DEGREE MURDER             1
# 2                                   VIO BAIL BOND/CLASS 1             1
# 3                         POSS AMT CON SUB EXCEPT (A)/(D)             1
# 4       DUI LIC SUSPENDED OR REVOKED (EFFECTIVE 4-13-2...             1
# ...                                                   ...           ...
# 135160                  AGGRAVATED UNLAWFUL USE OF WEAPON             1
# 135161                                   DOMESTIC BATTERY             1
# 135162                       DRIVING ON SUSPENDED LICENSE             1
# 135163                       DRIVING ON SUSPENDED LICENSE             1
# 135164                       DRIVING ON SUSPENDED LICENSE             1
#
#               DISPOSITION_DATE  ...  \
# 0       12/17/2014 12:00:00 AM  ...
# 1         8/6/2014 12:00:00 AM  ...
# 2        12/2/2013 12:00:00 AM  ...
# 3        9/10/2012 12:00:00 AM  ...
# 4        9/19/2014 12:00:00 AM  ...
# ...                        ...  ...
# 135160   3/19/2021 12:00:00 AM  ...
# 135161   3/23/2021 12:00:00 AM  ...
# 135162   3/11/2021 12:00:00 AM  ...
# 135163   3/11/2021 12:00:00 AM  ...
# 135164   3/21/2021 12:00:00 AM  ...
#
#                        simplified_offense_derived is_black_derived  \
# 0                                        Homicide             True
# 1                                        Homicide             True
# 2                               PROMIS Conversion            False
# 3                                       Narcotics             True
# 4                               PROMIS Conversion            False
# ...                                           ...              ...
# 135160               UUW - Unlawful Use of Weapon             True
# 135161                                    Battery             True
# 135162  Driving With Suspended Or Revoked License            False
# 135163  Driving With Suspended Or Revoked License            False
# 135164  Driving With Suspended Or Revoked License            False
#
#        is_hisp_derived is_white_derived is_other_derived is_male_derived  \
# 0                False            False            False            True
# 1                False            False            False            True
# 2                 True            False            False            True
# 3                False            False            False           False
# 4                False             True            False            True
# ...                ...              ...              ...             ...
# 135160           False            False            False           False
# 135161           False            False            False            True
# 135162           False             True            False            True
# 135163           False             True            False            True
# 135164           False             True            False            True
#
#        age_derived sentenceymd_derived sentenceym_derived judgeid_derived
# 0             27.0          2014-10-16         2014-10-01        judge_40
# 1             30.0          2014-08-06         2014-08-01       judge_310
# 2             38.0          2013-12-02         2013-12-01       judge_162
# 3             33.0          2012-09-10         2012-09-01       judge_331
# 4             49.0          2014-09-19         2014-09-01       judge_314
# ...            ...                 ...                ...             ...
# 135160        19.0          2021-03-19         2021-03-01         judge_8
# 135161        32.0          2021-03-23         2021-03-01       judge_294
# 135162        29.0          2021-03-11         2021-03-01        judge_99
# 135163        29.0          2021-03-11         2021-03-01        judge_99
# 135164        30.0          2021-03-11         2021-03-01        judge_99
#
# [135165 rows x 52 columns]>
# Index(['CASE_ID', 'CASE_PARTICIPANT_ID', 'RECEIVED_DATE', 'OFFENSE_CATEGORY',
#        'PRIMARY_CHARGE_FLAG', 'CHARGE_ID', 'CHARGE_VERSION_ID',
#        'DISPOSITION_CHARGED_OFFENSE_TITLE', 'CHARGE_COUNT', 'DISPOSITION_DATE',
#        'DISPOSITION_CHARGED_CHAPTER', 'DISPOSITION_CHARGED_ACT',
#        'DISPOSITION_CHARGED_SECTION', 'DISPOSITION_CHARGED_CLASS',
#        'DISPOSITION_CHARGED_AOIC', 'CHARGE_DISPOSITION',
#        'CHARGE_DISPOSITION_REASON', 'SENTENCE_JUDGE', 'SENTENCE_COURT_NAME',
#        'SENTENCE_COURT_FACILITY', 'SENTENCE_PHASE', 'SENTENCE_DATE',
#        'SENTENCE_TYPE', 'CURRENT_SENTENCE_FLAG', 'COMMITMENT_TYPE',
#        'COMMITMENT_TERM', 'COMMITMENT_UNIT', 'LENGTH_OF_CASE_in_Days',
#        'AGE_AT_INCIDENT', 'RACE', 'GENDER', 'INCIDENT_CITY',
#        'INCIDENT_BEGIN_DATE', 'INCIDENT_END_DATE', 'LAW_ENFORCEMENT_AGENCY',
#        'LAW_ENFORCEMENT_UNIT', 'ARREST_DATE', 'FELONY_REVIEW_DATE',
#        'FELONY_REVIEW_RESULT', 'ARRAIGNMENT_DATE', 'UPDATED_OFFENSE_CATEGORY',
#        'is_changed_offense', 'simplified_offense_derived', 'is_black_derived',
#        'is_hisp_derived', 'is_white_derived', 'is_other_derived',
#        'is_male_derived', 'age_derived', 'sentenceymd_derived',
#        'sentenceym_derived', 'judgeid_derived'],
#       dtype='object')

# %% [markdown]
# ## Create Term Length and Sentence Length Variables

# %%
## Creating Term Length Variable

## subsetting to just units of days, years, months, and life sentences (Note: we are equating one life sentence to be 100 years)

sentencing_df = sentencing_data_cleaned[sentencing_data_cleaned["COMMITMENT_UNIT"].isin(["Year(s)", "Natural Life", "Days", "Months"]) & sentencing_data_cleaned["COMMITMENT_TYPE"].isin(["Illinois Department of Corrections", "Cook County Department of Corrections"]) & sentencing_data_cleaned["CHARGE_DISPOSITION"].isin(["Plea Of Guilty", "Verdict Guilty"]) & sentencing_data_cleaned["PRIMARY_CHARGE_FLAG"] == True]

print(sentencing_df.shape)

## Creating sentence length variable (in years)

sentencing_df["COMMITMENT_TERM"] = sentencing_df["COMMITMENT_TERM"].astype(float)


sentencing_df["sentence_length"] = sentencing_df.apply(lambda row: row["COMMITMENT_TERM"] if row["COMMITMENT_UNIT"] == "Year(s)" else  
                                                       100 if row["COMMITMENT_UNIT"] == "Natural Life" else
                                                       row["COMMITMENT_TERM"] / 365 if row["COMMITMENT_UNIT"] == "Days" else 
                                                       row["COMMITMENT_TERM"] / 12 if row["COMMITMENT_UNIT"] == "Months" else None, axis = 1)


print(sentencing_df["sentence_length"].head)
# Out:
# (69346, 52)
# /var/folders/k3/stjkbqfd2rjbs1gs8py1dffc0000gn/T/ipykernel_65703/305593502.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentencing_df["COMMITMENT_TERM"] = sentencing_df["COMMITMENT_TERM"].astype(float)
# <bound method NDFrame.head of 0          62.000000
# 1         100.000000
# 2           3.000000
# 7          20.000000
# 8           6.000000
#              ...
# 135158      1.000000
# 135159      0.328767
# 135162      0.123288
# 135163      0.123288
# 135164      0.123288
# Name: sentence_length, Length: 69346, dtype: float64>
# /var/folders/k3/stjkbqfd2rjbs1gs8py1dffc0000gn/T/ipykernel_65703/305593502.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentencing_df["sentence_length"] = sentencing_df.apply(lambda row: row["COMMITMENT_TERM"] if row["COMMITMENT_UNIT"] == "Year(s)" else

# %% [markdown]
# ## Make sentencing unit standardizable by creating Z score

# %%
## Need to convert sentencing unit to something standardizable across crimes 
## To do this will use a z score (how many standard deviations something is from the mean) grouped by the exact same charge type


sentencing_df["sentence_length_zscore"] = sentencing_df.groupby("DISPOSITION_CHARGED_OFFENSE_TITLE")["sentence_length"].transform(zscore)


print(sentencing_df["sentence_length_zscore"].head())
# Out:
# 0    1.071864
# 1    2.846758
# 2   -0.734968
# 7    0.836916
# 8    0.064078
# Name: sentence_length_zscore, dtype: float64
# /var/folders/k3/stjkbqfd2rjbs1gs8py1dffc0000gn/T/ipykernel_65703/1866122673.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentencing_df["sentence_length_zscore"] = sentencing_df.groupby("DISPOSITION_CHARGED_OFFENSE_TITLE")["sentence_length"].transform(zscore)

# %% [markdown]
# # Eliminate Outliers That Would Skew Z Scores Before Conducting Analysis

# %%
## Eliminating outliers by subsetting to judges that have seen a certain number of cases and eliminating crazy z scores

## Examples of why we need to eliminate outliers: 

sentencing_df[sentencing_df["sentence_length_zscore"] == max(sentencing_df["sentence_length_zscore"])]
sentencing_df[sentencing_df["sentence_length_zscore"] == min(sentencing_df["sentence_length_zscore"])]


## using IQR +/- 1.5 to remove outliers 

q1 = sentencing_df["sentence_length_zscore"].quantile(.25)
q3 = sentencing_df["sentence_length_zscore"].quantile(.75)

IQR = q3 - q1

sentencing_df_no_outliers = sentencing_df.loc[(sentencing_df["sentence_length_zscore"] > ((q1 - 1.5) * IQR)) & (sentencing_df["sentence_length_zscore"] < ((q3 + 1.5) * IQR))]

## Checking to see that this method worked and brought max and min magnitudes closer: 

sentencing_df_no_outliers[sentencing_df_no_outliers["sentence_length_zscore"] == max(sentencing_df_no_outliers["sentence_length_zscore"])]
sentencing_df_no_outliers[sentencing_df_no_outliers["sentence_length_zscore"] == min(sentencing_df_no_outliers["sentence_length_zscore"])]

## How many rows did we lose 

print(sentencing_df.shape, sentencing_df_no_outliers.shape)
# Out:
#              CASE_ID  CASE_PARTICIPANT_ID         RECEIVED_DATE  \
# 116222  429410550059         853817163984  3/1/2018 12:00:00 AM
#
#        OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG     CHARGE_ID  CHARGE_VERSION_ID  \
# 116222        Narcotics                 True  421881792765       797531172032
#
#            DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 116222  POSSESSION OF A CONTROLLED SUBSTANCE             1
#
#              DISPOSITION_DATE  ... is_hisp_derived is_white_derived  \
# 116222  8/30/2018 12:00:00 AM  ...           False            False
#
#        is_other_derived is_male_derived age_derived sentenceymd_derived  \
# 116222            False            True        31.0          2018-08-30
#
#        sentenceym_derived judgeid_derived sentence_length  \
# 116222         2018-08-01         judge_4           364.0
#
#        sentence_length_zscore
# 116222              98.691965
#
# [1 rows x 54 columns]
#              CASE_ID  CASE_PARTICIPANT_ID         RECEIVED_DATE  \
# 133901  440611743299         888607576468  1/9/2020 12:00:00 AM
#
#                                  OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG  \
# 133901  Driving With Suspended Or Revoked License                 True
#
#            CHARGE_ID  CHARGE_VERSION_ID  \
# 133901  440285743720       822116942245
#
#                         DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 133901  FELONY DRIVING WHILE DRIVER?S LICENSE, PERMIT,...             1
#
#               DISPOSITION_DATE  ... is_hisp_derived is_white_derived  \
# 133901  10/20/2020 12:00:00 AM  ...           False            False
#
#        is_other_derived is_male_derived age_derived sentenceymd_derived  \
# 133901            False            True        56.0          2020-10-20
#
#        sentenceym_derived judgeid_derived sentence_length  \
# 133901         2020-10-01       judge_314        0.082192
#
#        sentence_length_zscore
# 133901              -3.482217
#
# [1 rows x 54 columns]
#              CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 8505    387465037559         724679353540    8/3/2011 12:00:00 AM
# 19024   391597821734         736187668018    4/6/2012 12:00:00 AM
# 28289   394963583958         745754179742   9/21/2012 12:00:00 AM
# 38138   398617181339         756493455017   3/28/2013 12:00:00 AM
# 39817   399292125410         758508962474   4/15/2013 12:00:00 AM
# 43780   400806197077         763210963856    5/6/2013 12:00:00 AM
# 51373   403730954721         772292779869   12/7/2013 12:00:00 AM
# 83295   415709156030         809808190144   10/1/2015 12:00:00 AM
# 108684  425841687824         842380666763   7/11/2017 12:00:00 AM
# 113699  428262146525         850151841415  12/13/2017 12:00:00 AM
# 114108  428436903584         850728738782  12/27/2017 12:00:00 AM
#
#                                  OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG  \
# 8505    Aggravated Assault Police Officer Firearm                 True
# 19024              Aggravated Fleeing and Eluding                 True
# 28289           Aggravated Assault Police Officer                 True
# 38138           Aggravated Assault Police Officer                 True
# 39817           Aggravated Battery Police Officer                 True
# 43780           Aggravated Assault Police Officer                 True
# 51373           Aggravated Assault Police Officer                 True
# 83295           Aggravated Assault Police Officer                 True
# 108684          Aggravated Assault Police Officer                 True
# 113699          Aggravated Assault Police Officer                 True
# 114108               UUW - Unlawful Use of Weapon                 True
#
#            CHARGE_ID  CHARGE_VERSION_ID DISPOSITION_CHARGED_OFFENSE_TITLE  \
# 8505    348806151893       648725011450                AGGRAVATED ASSAULT
# 19024   356411519518       663054231311                AGGRAVATED ASSAULT
# 28289   361516019164       672662910049                AGGRAVATED ASSAULT
# 38138   367681387982       684266304679                AGGRAVATED ASSAULT
# 39817   369518314049       687722958985                AGGRAVATED ASSAULT
# 43780   371283144652       691027804874                AGGRAVATED ASSAULT
# 51373   376043908810       699994497492                AGGRAVATED ASSAULT
# 83295   395903494339       737604869383                AGGRAVATED ASSAULT
# 108684  415173495830       774179674317                AGGRAVATED ASSAULT
# 113699  419733911017       782920943114                AGGRAVATED ASSAULT
# 114108  420437419965       784259099279                AGGRAVATED ASSAULT
#
#         CHARGE_COUNT        DISPOSITION_DATE  ... is_hisp_derived  \
# 8505               1    1/4/2013 12:00:00 AM  ...           False
# 19024              1    8/3/2012 12:00:00 AM  ...           False
# 28289              1    5/1/2013 12:00:00 AM  ...           False
# 38138              1    9/9/2015 12:00:00 AM  ...            True
# 39817              1    4/2/2014 12:00:00 AM  ...           False
# 43780              1  10/22/2013 12:00:00 AM  ...           False
# 51373              1    9/1/2016 12:00:00 AM  ...           False
# 83295              1   2/26/2016 12:00:00 AM  ...           False
# 108684             1   3/27/2018 12:00:00 AM  ...           False
# 113699             1   8/30/2018 12:00:00 AM  ...           False
# 114108             1   5/10/2019 12:00:00 AM  ...           False
#
#        is_white_derived is_other_derived is_male_derived age_derived  \
# 8505              False            False            True        20.0
# 19024             False            False            True        42.0
# 28289             False            False            True        38.0
# 38138             False            False            True        31.0
# 39817             False            False           False        36.0
# 43780             False            False            True        27.0
# 51373             False            False            True        36.0
# 83295             False            False            True        27.0
# 108684            False            False            True        20.0
# 113699            False            False            True        22.0
# 114108            False            False            True        27.0
#
#        sentenceymd_derived sentenceym_derived judgeid_derived sentence_length  \
# 8505            2013-01-04         2013-01-01       judge_310             4.0
# 19024           2012-08-03         2012-08-01       judge_188             4.0
# 28289           2013-04-24         2013-04-01        judge_31             4.0
# 38138           2015-09-09         2015-09-01       judge_222             4.0
# 39817           2017-03-20         2017-03-01        judge_61             4.0
# 43780           2013-10-22         2013-10-01       judge_331             4.0
# 51373           2016-09-01         2016-09-01       judge_109             4.0
# 83295           2016-02-25         2016-02-01       judge_115             4.0
# 108684          2018-03-27         2018-03-01       judge_334             4.0
# 113699          2018-08-30         2018-08-01       judge_310             4.0
# 114108          2019-05-10         2019-05-01       judge_315             4.0
#
#        sentence_length_zscore
# 8505                 1.542805
# 19024                1.542805
# 28289                1.542805
# 38138                1.542805
# 39817                1.542805
# 43780                1.542805
# 51373                1.542805
# 83295                1.542805
# 108684               1.542805
# 113699               1.542805
# 114108               1.542805
#
# [11 rows x 54 columns]
#              CASE_ID  CASE_PARTICIPANT_ID          RECEIVED_DATE  \
# 103853  423700546708         835575486134  2/28/2017 12:00:00 AM
#
#        OFFENSE_CATEGORY  PRIMARY_CHARGE_FLAG     CHARGE_ID  CHARGE_VERSION_ID  \
# 103853   Aggravated DUI                 True  411015085757       766301704956
#
#                         DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 103853  AGGRAVATED FLEEING OR ATTEMPT TO ELUDE A PEACE...             1
#
#               DISPOSITION_DATE  ... is_hisp_derived is_white_derived  \
# 103853  11/20/2018 12:00:00 AM  ...           False            False
#
#        is_other_derived is_male_derived age_derived sentenceymd_derived  \
# 103853            False            True        20.0          2018-11-20
#
#        sentenceym_derived judgeid_derived sentence_length  \
# 103853         2018-11-01        judge_92        0.054795
#
#        sentence_length_zscore
# 103853               -1.74384
#
# [1 rows x 54 columns]
# (69346, 54) (65857, 54)

# %% [markdown]
# ## Export data as csv file to Data folder

# %%
## Exporting CSV to be used in the next file (Creating dependent variables)


sentencing_df_no_outliers.to_csv(r'../Data/sentencing_data_withZ.csv')
